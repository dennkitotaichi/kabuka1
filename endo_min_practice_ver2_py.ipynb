# %% [markdown]
# <a href="https://colab.research.google.com/github/dennkitotaichi/kabuka1/blob/master/endo_min_practice_ver2_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#MB5 = Make_base_dataset_min(sales_df=sales_df, days=1, id_no=1)の場合
import pandas as pd
import itertools
import numpy as np

#calendar_df = pd.read_csv("/content/drive/My Drive/calendar_min.csv")
sales_df = pd.read_csv("/content/drive/My Drive/practice/practice_train2.csv")

#print("calendar_df")
#print(calendar_df)
print("sales_df")
print(sales_df)


class Make_base_dataset_min():
    def __init__(self, sales_df, days, id_no):
        self.sales_df = sales_df
        self.id_no = id_no
        self.days = days

    def copy_feature(self, feature_array):
        feature_array = feature_array[:self.id_no].tolist()
        print("feature_array_[:self.id_no]_.tolist()を実行した場合")
        print(feature_array)
        print("---------------------------------------------")


        print("---------------------------------------------")

        print("feature_array for_i_in_range(int(self.days))を実行した場合")
        print([feature_array for i in range(int(self.days))])

        print("---------------------------------------------")
        print("Movement when returning　return listを実行した場合")
        print(itertools.chain.from_iterable([feature_array for i in range(int(self.days))]))
        return list(itertools.chain.from_iterable([feature_array for i in range(int(self.days))]))

    def make_id_feature(self):
        print(self.copy_feature(self.sales_df["id"].values))
        return self.copy_feature(self.sales_df["id"].values)
    
    def make_id_feature_p(self):
        MB_5_p=self.sales_df["id"].values
        print(MB_5_p)

    def make_id_feature_p2(self):
        MB_5_p2=self.sales_df["item_id"].values
        print(MB_5_p2)

MB5 = Make_base_dataset_min(sales_df=sales_df, days=1, id_no=1)
print("MB5.make_id_feature(),idの列をスライスする")
MB5.make_id_feature()
print("---------------------------------------------")
print("MB5.make_id_feature_p(),self.sales_df,idのvalues:値を抜いて表示させる")
MB5.make_id_feature_p()
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 65
# sales_df
#             id   item_id dept_id cat_id
# 0    practice1  HO_1_001   HOB_1    HOB
# 1    practice2  HO_1_002   HOB_2    HOB
# 2    practice3  HO_1_003   HOB_3    HOB
# 3    practice4  HO_1_004   HOB_4    HOB
# 4    practice5  HO_1_005   HOB_5    HOB
# 5    practice6  HO_1_006   HOB_6    HOB
# 6    practice7  HO_1_007   HOB_7    HOB
# 7    practice8  HO_1_008   HOB_8    HOB
# 8    practice9  HO_1_009   HOB_9    HOB
# 9   practice10  HO_1_010  HOB_10    HOB
# 10  practice11  HO_1_011  HOB_11    HOB
# 11  practice12  HO_1_012  HOB_12    HOB
# 12  practice13  HO_1_013  HOB_13    HOB
# 13  practice14  HO_1_014  HOB_14    HOB
# 14  practice15  HO_1_015  HOB_15    HOB
# MB5.make_id_feature(),idの列をスライスする
# feature_array_[:self.id_no]_.tolist()を実行した場合
# ['practice1']
# ---------------------------------------------
# ---------------------------------------------
# feature_array for_i_in_range(int(self.days))を実行した場合
# [['practice1']]
# ---------------------------------------------
# Movement when returning　return listを実行した場合
# <itertools.chain object at 0x7f177cb9bc50>
# ['practice1']
# feature_array_[:self.id_no]_.tolist()を実行した場合
# ['practice1']
# ---------------------------------------------
# ---------------------------------------------
# feature_array for_i_in_range(int(self.days))を実行した場合
# [['practice1']]
# ---------------------------------------------
# Movement when returning　return listを実行した場合
# <itertools.chain object at 0x7f177cb9b0b8>
# ---------------------------------------------
# MB5.make_id_feature_p(),self.sales_df,idのvalues:値を抜いて表示させる
# ['practice1' 'practice2' 'practice3' 'practice4' 'practice5' 'practice6'
#  'practice7' 'practice8' 'practice9' 'practice10' 'practice11'
#  'practice12' 'practice13' 'practice14' 'practice15']

# %%
#MB5 = Make_base_dataset_min(sales_df=sales_df, days=10, id_no=1)の場合
import pandas as pd
import itertools
import numpy as np

calendar_df = pd.read_csv("/content/drive/My Drive/calendar_min.csv")
sales_df = pd.read_csv("/content/drive/My Drive/practice/practice_train2.csv")

#print("calendar_df")
#print(calendar_df)
print("sales_df")
print(sales_df)


class Make_base_dataset_min():
    def __init__(self, sales_df, days, id_no):
        self.sales_df = sales_df
        self.id_no = id_no
        self.days = days

    def copy_feature(self, feature_array):
        feature_array = feature_array[:self.id_no].tolist()
        print("feature_array_[:self.id_no]_.tolist()を実行した場合")
        print(feature_array)
        print("---------------------------------------------")

        #print("for_i_in_range_int_self.days_を実行した場合")
        #print(for i in range(int(self.days))


        print("---------------------------------------------")

        print("feature_array for_i_in_range(int(self.days))を実行した場合")
        print([feature_array for i in range(int(self.days))])

        print("---------------------------------------------")
        print("Movement when returning　return listを実行した場合")
        print(itertools.chain.from_iterable([feature_array for i in range(int(self.days))]))
        return list(itertools.chain.from_iterable([feature_array for i in range(int(self.days))]))

    def make_id_feature(self):
        print(self.copy_feature(self.sales_df["id"].values))
        return self.copy_feature(self.sales_df["id"].values)
    
    def make_id_feature_p(self):
        MB_5_p=self.sales_df["id"].values
        print(MB_5_p)

    def make_id_feature_p2(self):
        MB_5_p2=self.sales_df["item_id"].values
        print(MB_5_p2)

MB5 = Make_base_dataset_min(sales_df=sales_df, days=15, id_no=1)
print("MB5.make_id_feature(),idの列をスライスする")
MB5.make_id_feature()
print("---------------------------------------------")
print("MB5.make_id_feature_p(),self.sales_df,idのvalues:値を抜いて表示させる")
MB5.make_id_feature_p()
# Out:
# sales_df
#             id   item_id dept_id cat_id
# 0    practice1  HO_1_001   HOB_1    HOB
# 1    practice2  HO_1_002   HOB_2    HOB
# 2    practice3  HO_1_003   HOB_3    HOB
# 3    practice4  HO_1_004   HOB_4    HOB
# 4    practice5  HO_1_005   HOB_5    HOB
# 5    practice6  HO_1_006   HOB_6    HOB
# 6    practice7  HO_1_007   HOB_7    HOB
# 7    practice8  HO_1_008   HOB_8    HOB
# 8    practice9  HO_1_009   HOB_9    HOB
# 9   practice10  HO_1_010  HOB_10    HOB
# 10  practice11  HO_1_011  HOB_11    HOB
# 11  practice12  HO_1_012  HOB_12    HOB
# 12  practice13  HO_1_013  HOB_13    HOB
# 13  practice14  HO_1_014  HOB_14    HOB
# 14  practice15  HO_1_015  HOB_15    HOB
# MB5.make_id_feature(),idの列をスライスする
# feature_array_[:self.id_no]_.tolist()を実行した場合
# ['practice1']
# ---------------------------------------------
# ---------------------------------------------
# feature_array for_i_in_range(int(self.days))を実行した場合
# [['practice1'], ['practice1'], ['practice1'], ['practice1'], ['practice1'], ['practice1'], ['practice1'], ['practice1'], ['practice1'], ['practice1'], ['practice1'], ['practice1'], ['practice1'], ['practice1'], ['practice1']]
# ---------------------------------------------
# Movement when returning　return listを実行した場合
# <itertools.chain object at 0x7f177cb9bd30>
# ['practice1', 'practice1', 'practice1', 'practice1', 'practice1', 'practice1', 'practice1', 'practice1', 'practice1', 'practice1', 'practice1', 'practice1', 'practice1', 'practice1', 'practice1']
# feature_array_[:self.id_no]_.tolist()を実行した場合
# ['practice1']
# ---------------------------------------------
# ---------------------------------------------
# feature_array for_i_in_range(int(self.days))を実行した場合
# [['practice1'], ['practice1'], ['practice1'], ['practice1'], ['practice1'], ['practice1'], ['practice1'], ['practice1'], ['practice1'], ['practice1'], ['practice1'], ['practice1'], ['practice1'], ['practice1'], ['practice1']]
# ---------------------------------------------
# Movement when returning　return listを実行した場合
# <itertools.chain object at 0x7f177cc96b70>
# ---------------------------------------------
# MB5.make_id_feature_p(),self.sales_df,idのvalues:値を抜いて表示させる
# ['practice1' 'practice2' 'practice3' 'practice4' 'practice5' 'practice6'
#  'practice7' 'practice8' 'practice9' 'practice10' 'practice11'
#  'practice12' 'practice13' 'practice14' 'practice15']

# %%
#MB5 = Make_base_dataset_min(sales_df=sales_df, days=1, id_no=10)の場合
import pandas as pd
import itertools
import numpy as np

sales_df = pd.read_csv("/content/drive/My Drive/practice/practice_train2.csv")

print("sales_df")
print(sales_df)


class Make_base_dataset_min():
    def __init__(self, sales_df, days, id_no):
        self.sales_df = sales_df
        self.id_no = id_no
        self.days = days

    def copy_feature(self, feature_array):
        feature_array = feature_array[:self.id_no].tolist()
        print("feature_array_[:self.id_no]_.tolist()を実行した場合")
        print(feature_array)
        print("---------------------------------------------")

        #print("for_i_in_range_int_self.days_を実行した場合")
        #print(for i in range(int(self.days))

        print("---------------------------------------------")

        print("feature_array for_i_in_range(int(self.days))を実行した場合")
        print([feature_array for i in range(int(self.days))])

        print("---------------------------------------------")
        print("Movement when returning　return listを実行した場合")
        print(itertools.chain.from_iterable([feature_array for i in range(int(self.days))]))
        return list(itertools.chain.from_iterable([feature_array for i in range(int(self.days))]))

    def make_id_feature(self):
        print(self.copy_feature(self.sales_df["id"].values))
        return self.copy_feature(self.sales_df["id"].values)
    
    def make_id_feature_p(self):
        MB_5_p=self.sales_df["id"].values
        print(MB_5_p)

    def make_id_feature_p2(self):
        MB_5_p2=self.sales_df["item_id"].values
        print(MB_5_p2)

#
#
#以下の部分のdays=○, id_no=○を調節して遊んでます＾＾
MB5 = Make_base_dataset_min(sales_df=sales_df, days=1, id_no=10)
print("MB5.make_id_feature(),idの列をスライスする")
MB5.make_id_feature()
print("---------------------------------------------")
print("MB5.make_id_feature_p(),self.sales_df,idのvalues:値を抜いて表示させる")
MB5.make_id_feature_p()
# Out:
# sales_df
#             id   item_id dept_id cat_id
# 0    practice1  HO_1_001   HOB_1    HOB
# 1    practice2  HO_1_002   HOB_2    HOB
# 2    practice3  HO_1_003   HOB_3    HOB
# 3    practice4  HO_1_004   HOB_4    HOB
# 4    practice5  HO_1_005   HOB_5    HOB
# 5    practice6  HO_1_006   HOB_6    HOB
# 6    practice7  HO_1_007   HOB_7    HOB
# 7    practice8  HO_1_008   HOB_8    HOB
# 8    practice9  HO_1_009   HOB_9    HOB
# 9   practice10  HO_1_010  HOB_10    HOB
# 10  practice11  HO_1_011  HOB_11    HOB
# 11  practice12  HO_1_012  HOB_12    HOB
# 12  practice13  HO_1_013  HOB_13    HOB
# 13  practice14  HO_1_014  HOB_14    HOB
# 14  practice15  HO_1_015  HOB_15    HOB
# MB5.make_id_feature(),idの列をスライスする
# feature_array_[:self.id_no]_.tolist()を実行した場合
# ['practice1', 'practice2', 'practice3', 'practice4', 'practice5', 'practice6', 'practice7', 'practice8', 'practice9', 'practice10']
# ---------------------------------------------
# ---------------------------------------------
# feature_array for_i_in_range(int(self.days))を実行した場合
# [['practice1', 'practice2', 'practice3', 'practice4', 'practice5', 'practice6', 'practice7', 'practice8', 'practice9', 'practice10']]
# ---------------------------------------------
# Movement when returning　return listを実行した場合
# <itertools.chain object at 0x7f177cb56e48>
# ['practice1', 'practice2', 'practice3', 'practice4', 'practice5', 'practice6', 'practice7', 'practice8', 'practice9', 'practice10']
# feature_array_[:self.id_no]_.tolist()を実行した場合
# ['practice1', 'practice2', 'practice3', 'practice4', 'practice5', 'practice6', 'practice7', 'practice8', 'practice9', 'practice10']
# ---------------------------------------------
# ---------------------------------------------
# feature_array for_i_in_range(int(self.days))を実行した場合
# [['practice1', 'practice2', 'practice3', 'practice4', 'practice5', 'practice6', 'practice7', 'practice8', 'practice9', 'practice10']]
# ---------------------------------------------
# Movement when returning　return listを実行した場合
# <itertools.chain object at 0x7f177cb945f8>
# ---------------------------------------------
# MB5.make_id_feature_p(),self.sales_df,idのvalues:値を抜いて表示させる
# ['practice1' 'practice2' 'practice3' 'practice4' 'practice5' 'practice6'
#  'practice7' 'practice8' 'practice9' 'practice10' 'practice11'
#  'practice12' 'practice13' 'practice14' 'practice15']

# %%
#MB5 = Make_base_dataset_min(sales_df=sales_df, days=1, id_no=15)の場合
import pandas as pd
import itertools
import numpy as np

sales_df = pd.read_csv("/content/drive/My Drive/practice/practice_train2.csv")

print("sales_df")
print(sales_df)

class Make_base_dataset_min():
    def __init__(self, sales_df, days, id_no):
        self.sales_df = sales_df
        self.id_no = id_no
        self.days = days

    def copy_feature(self, feature_array):
        feature_array = feature_array[:self.id_no].tolist()
        print("feature_array_[:self.id_no]_.tolist()を実行した場合")
        print(feature_array)
        print("---------------------------------------------")

        #print("for_i_in_range_int_self.days_を実行した場合")
        #print(for i in range(int(self.days))

        print("---------------------------------------------")

        print("feature_array for_i_in_range(int(self.days))を実行した場合")
        print([feature_array for i in range(int(self.days))])

        print("---------------------------------------------")
        print("Movement when returning　return listを実行した場合")
        print(itertools.chain.from_iterable([feature_array for i in range(int(self.days))]))
        return list(itertools.chain.from_iterable([feature_array for i in range(int(self.days))]))

    def make_id_feature(self):
        print(self.copy_feature(self.sales_df["id"].values))
        return self.copy_feature(self.sales_df["id"].values)
    
    def make_id_feature_p(self):
        MB_5_p=self.sales_df["id"].values
        print(MB_5_p)

    def make_id_feature_p2(self):
        MB_5_p2=self.sales_df["item_id"].values
        print(MB_5_p2)

#
#
#以下の部分のdays=○, id_no=○を調節して遊んでます＾＾
MB5 = Make_base_dataset_min(sales_df=sales_df, days=1, id_no=15)
print("MB5.make_id_feature(),idの列をスライスする")
MB5.make_id_feature()
print("---------------------------------------------")
print("MB5.make_id_feature_p(),self.sales_df,idのvalues:値を抜いて表示させる")
MB5.make_id_feature_p()
# Out:
# sales_df
#             id   item_id dept_id cat_id
# 0    practice1  HO_1_001   HOB_1    HOB
# 1    practice2  HO_1_002   HOB_2    HOB
# 2    practice3  HO_1_003   HOB_3    HOB
# 3    practice4  HO_1_004   HOB_4    HOB
# 4    practice5  HO_1_005   HOB_5    HOB
# 5    practice6  HO_1_006   HOB_6    HOB
# 6    practice7  HO_1_007   HOB_7    HOB
# 7    practice8  HO_1_008   HOB_8    HOB
# 8    practice9  HO_1_009   HOB_9    HOB
# 9   practice10  HO_1_010  HOB_10    HOB
# 10  practice11  HO_1_011  HOB_11    HOB
# 11  practice12  HO_1_012  HOB_12    HOB
# 12  practice13  HO_1_013  HOB_13    HOB
# 13  practice14  HO_1_014  HOB_14    HOB
# 14  practice15  HO_1_015  HOB_15    HOB
# MB5.make_id_feature(),idの列をスライスする
# feature_array_[:self.id_no]_.tolist()を実行した場合
# ['practice1', 'practice2', 'practice3', 'practice4', 'practice5', 'practice6', 'practice7', 'practice8', 'practice9', 'practice10', 'practice11', 'practice12', 'practice13', 'practice14', 'practice15']
# ---------------------------------------------
# ---------------------------------------------
# feature_array for_i_in_range(int(self.days))を実行した場合
# [['practice1', 'practice2', 'practice3', 'practice4', 'practice5', 'practice6', 'practice7', 'practice8', 'practice9', 'practice10', 'practice11', 'practice12', 'practice13', 'practice14', 'practice15']]
# ---------------------------------------------
# Movement when returning　return listを実行した場合
# <itertools.chain object at 0x7f177cb9bc18>
# ['practice1', 'practice2', 'practice3', 'practice4', 'practice5', 'practice6', 'practice7', 'practice8', 'practice9', 'practice10', 'practice11', 'practice12', 'practice13', 'practice14', 'practice15']
# feature_array_[:self.id_no]_.tolist()を実行した場合
# ['practice1', 'practice2', 'practice3', 'practice4', 'practice5', 'practice6', 'practice7', 'practice8', 'practice9', 'practice10', 'practice11', 'practice12', 'practice13', 'practice14', 'practice15']
# ---------------------------------------------
# ---------------------------------------------
# feature_array for_i_in_range(int(self.days))を実行した場合
# [['practice1', 'practice2', 'practice3', 'practice4', 'practice5', 'practice6', 'practice7', 'practice8', 'practice9', 'practice10', 'practice11', 'practice12', 'practice13', 'practice14', 'practice15']]
# ---------------------------------------------
# Movement when returning　return listを実行した場合
# <itertools.chain object at 0x7f177cb2a748>
# ---------------------------------------------
# MB5.make_id_feature_p(),self.sales_df,idのvalues:値を抜いて表示させる
# ['practice1' 'practice2' 'practice3' 'practice4' 'practice5' 'practice6'
#  'practice7' 'practice8' 'practice9' 'practice10' 'practice11'
#  'practice12' 'practice13' 'practice14' 'practice15']

# %%
#MB5 = Make_base_dataset_min(sales_df=sales_df, days=2, id_no=15)の場合
import pandas as pd
import itertools
import numpy as np

sales_df = pd.read_csv("/content/drive/My Drive/practice/practice_train2.csv")

print("sales_df")
print(sales_df)

class Make_base_dataset_min():
    def __init__(self, sales_df, days, id_no):
        self.sales_df = sales_df
        self.id_no = id_no
        self.days = days

    def copy_feature(self, feature_array):
        feature_array = feature_array[:self.id_no].tolist()
        print("feature_array_[:self.id_no]_.tolist()を実行した場合")
        print(feature_array)
        print("---------------------------------------------")

        #print("for_i_in_range_int_self.days_を実行した場合")
        #print(for i in range(int(self.days))

        print("---------------------------------------------")

        print("feature_array for_i_in_range(int(self.days))を実行した場合")
        print([feature_array for i in range(int(self.days))])

        print("---------------------------------------------")
        print("Movement when returning　return listを実行した場合")
        print(itertools.chain.from_iterable([feature_array for i in range(int(self.days))]))
        return list(itertools.chain.from_iterable([feature_array for i in range(int(self.days))]))

    def make_id_feature(self):
        print(self.copy_feature(self.sales_df["id"].values))
        return self.copy_feature(self.sales_df["id"].values)
    
    def make_id_feature_p(self):
        MB_5_p=self.sales_df["id"].values
        print(MB_5_p)

    def make_id_feature_p2(self):
        MB_5_p2=self.sales_df["item_id"].values
        print(MB_5_p2)

#
#
#以下の部分のdays=○, id_no=○を調節して遊んでます＾＾
MB5 = Make_base_dataset_min(sales_df=sales_df, days=2, id_no=15)
print("MB5.make_id_feature(),idの列をスライスする")
MB5.make_id_feature()
print("---------------------------------------------")
print("MB5.make_id_feature_p(),self.sales_df,idのvalues:値を抜いて表示させる")
MB5.make_id_feature_p()
# Out:
# sales_df
#             id   item_id dept_id cat_id
# 0    practice1  HO_1_001   HOB_1    HOB
# 1    practice2  HO_1_002   HOB_2    HOB
# 2    practice3  HO_1_003   HOB_3    HOB
# 3    practice4  HO_1_004   HOB_4    HOB
# 4    practice5  HO_1_005   HOB_5    HOB
# 5    practice6  HO_1_006   HOB_6    HOB
# 6    practice7  HO_1_007   HOB_7    HOB
# 7    practice8  HO_1_008   HOB_8    HOB
# 8    practice9  HO_1_009   HOB_9    HOB
# 9   practice10  HO_1_010  HOB_10    HOB
# 10  practice11  HO_1_011  HOB_11    HOB
# 11  practice12  HO_1_012  HOB_12    HOB
# 12  practice13  HO_1_013  HOB_13    HOB
# 13  practice14  HO_1_014  HOB_14    HOB
# 14  practice15  HO_1_015  HOB_15    HOB
# MB5.make_id_feature(),idの列をスライスする
# feature_array_[:self.id_no]_.tolist()を実行した場合
# ['practice1', 'practice2', 'practice3', 'practice4', 'practice5', 'practice6', 'practice7', 'practice8', 'practice9', 'practice10', 'practice11', 'practice12', 'practice13', 'practice14', 'practice15']
# ---------------------------------------------
# ---------------------------------------------
# feature_array for_i_in_range(int(self.days))を実行した場合
# [['practice1', 'practice2', 'practice3', 'practice4', 'practice5', 'practice6', 'practice7', 'practice8', 'practice9', 'practice10', 'practice11', 'practice12', 'practice13', 'practice14', 'practice15'], ['practice1', 'practice2', 'practice3', 'practice4', 'practice5', 'practice6', 'practice7', 'practice8', 'practice9', 'practice10', 'practice11', 'practice12', 'practice13', 'practice14', 'practice15']]
# ---------------------------------------------
# Movement when returning　return listを実行した場合
# <itertools.chain object at 0x7f177cb9bac8>
# ['practice1', 'practice2', 'practice3', 'practice4', 'practice5', 'practice6', 'practice7', 'practice8', 'practice9', 'practice10', 'practice11', 'practice12', 'practice13', 'practice14', 'practice15', 'practice1', 'practice2', 'practice3', 'practice4', 'practice5', 'practice6', 'practice7', 'practice8', 'practice9', 'practice10', 'practice11', 'practice12', 'practice13', 'practice14', 'practice15']
# feature_array_[:self.id_no]_.tolist()を実行した場合
# ['practice1', 'practice2', 'practice3', 'practice4', 'practice5', 'practice6', 'practice7', 'practice8', 'practice9', 'practice10', 'practice11', 'practice12', 'practice13', 'practice14', 'practice15']
# ---------------------------------------------
# ---------------------------------------------
# feature_array for_i_in_range(int(self.days))を実行した場合
# [['practice1', 'practice2', 'practice3', 'practice4', 'practice5', 'practice6', 'practice7', 'practice8', 'practice9', 'practice10', 'practice11', 'practice12', 'practice13', 'practice14', 'practice15'], ['practice1', 'practice2', 'practice3', 'practice4', 'practice5', 'practice6', 'practice7', 'practice8', 'practice9', 'practice10', 'practice11', 'practice12', 'practice13', 'practice14', 'practice15']]
# ---------------------------------------------
# Movement when returning　return listを実行した場合
# <itertools.chain object at 0x7f177cb9ba58>
# ---------------------------------------------
# MB5.make_id_feature_p(),self.sales_df,idのvalues:値を抜いて表示させる
# ['practice1' 'practice2' 'practice3' 'practice4' 'practice5' 'practice6'
#  'practice7' 'practice8' 'practice9' 'practice10' 'practice11'
#  'practice12' 'practice13' 'practice14' 'practice15']
